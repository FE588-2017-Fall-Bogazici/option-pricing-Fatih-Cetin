# %%
# %matplotlib inline
import matplotlib.pylab as plt
import pandas as pd
import numpy as np

import pandas as pd

import numpy as np
import datetime

msft = pd.read_csv("msft.csv", index_col=0, parse_dates=True)
aapl = pd.read_csv("aapl.csv", index_col=0, parse_dates=True)

msft
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2014-12-31  46.730000  47.439999  46.450001  46.450001  43.050045   21552500
# 2015-01-02  46.660000  47.419998  46.540001  46.759998  43.337357   27913900
# 2015-01-05  46.369999  46.730000  46.250000  46.330002  42.938828   39673900
# 2015-01-06  46.380001  46.750000  45.540001  45.650002  42.308598   36447900
# 2015-01-07  45.980000  46.459999  45.490002  46.230000  42.846146   29114100
# 2015-01-08  46.750000  47.750000  46.720001  47.590000  44.106598   29645200
# 2015-01-09  47.610001  47.820000  46.900002  47.189999  43.735882   23942800
# 2015-01-12  47.419998  47.540001  46.360001  46.599998  43.189060   23651900
# 2015-01-13  46.970001  47.910000  46.060001  46.360001  42.966637   35270600
# 2015-01-14  45.959999  46.240002  45.619999  45.959999  42.595909   29719600
# 2015-01-15  46.220001  46.380001  45.410000  45.480000  42.151039   32750800
# ...

# %%
plt.figure(figsize=(10,5))
msft['Open'].plot()
plt.show()

# %%
x = aapl['2015-02-05':'2017-02-23']['Open']
y = aapl['2015-02-05':'2017-02-23']['Close']
Vol = aapl['2015-02-05':'2017-02-23']['Volume']

plt.plot(x)
plt.plot(y)
plt.legend()
plt.show()

# %%
a = msft['2015-02-05':'2017-02-23']['Open']
b = msft['2015-02-05':'2017-02-23']['Close']
Vol = msft['2015-02-05':'2017-02-23']['Volume']

plt.plot(a)
plt.plot(b)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
MV1 = msft['2015-01-01':'2015-08-01']['Close'].rolling(10).mean().plot()
MV2 = msft['2015-01-01':'2015-08-01']['Close'].rolling(5).mean().plot()
msft['2015-01-01':'2015-08-01']['Close'].plot
plt.show()

# %%
plt.figure(figsize=(10,5))
MV1 = aapl['2015-01-01':'2015-08-01']['Close'].rolling(10).mean().plot()
MV2 = aapl['2015-01-01':'2015-08-01']['Close'].rolling(5).mean().plot()
msft['2015-01-01':'2015-08-01']['Close'].plot
plt.show()

# %%
MV1 = aapl['2015-01-01':'2015-08-01']['Close'].rolling(10).mean()
MV2 = aapl['2015-01-01':'2015-08-01']['Close'].rolling(5).mean()

x = MV1 - MV2
x
# Out:
# Date
# 2015-01-02         NaN
# 2015-01-05         NaN
# 2015-01-06         NaN
# 2015-01-07         NaN
# 2015-01-08         NaN
# 2015-01-09         NaN
# 2015-01-12         NaN
# 2015-01-13         NaN
# 2015-01-14         NaN
# 2015-01-15   -0.662000
# 2015-01-16    0.208000
# 2015-01-20    0.561000
# 2015-01-21    1.024000
# 2015-01-22    0.969000
# 2015-01-23   -0.154000
# 2015-01-26   -1.467000
# 2015-01-27   -1.562000
# 2015-01-28   -2.204999
# 2015-01-29   -2.595000
# 2015-01-30   -2.396999
# 2015-02-02   -2.238999
# 2015-02-03   -3.148000
# 2015-02-04   -2.997000
# 2015-02-05   -2.451000
# 2015-02-06   -2.210000
# 2015-02-09   -1.766000
# 2015-02-10   -1.151999
# 2015-02-11   -1.258999
# 2015-02-12   -1.806999
# 2015-02-13   -2.445000
#                 ...
# 2015-06-19    0.356001
# 2015-06-22    0.199000
# 2015-06-23    0.274000
# 2015-06-24    0.035000
# 2015-06-25    0.002000
# 2015-06-26   -0.070001
# 2015-06-29    0.307000
# 2015-06-30    0.410000
# ...

# %%
# %matplotlib inline
import matplotlib.pylab as plt

x.plot(color='g')

idx=change[change<0]
idx.plot(marker='o',style=None)
ax=plt.gca()
ax.grid('on')

change = np.sign(x.shift(1))*np.sign(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-58d965b681b0> in <module>()
#       4 x.plot(color='g')
#       5
# ----> 6 idx=change[change<0]
#       7 idx.plot(marker='o',style=None)
#       8 ax=plt.gca()
#
# NameError: name 'change' is not defined

# %%
idx=change[change<0].index
idx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c09805d8fc77> in <module>()
# ----> 1 idx=change[change<0].index
#       2 idx
#
# NameError: name 'change' is not defined
